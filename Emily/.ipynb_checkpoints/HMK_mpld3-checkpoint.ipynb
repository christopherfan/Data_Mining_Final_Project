# %% [markdown]
# # HMK - mpld3

# %% [markdown]
# ## Parking violation tickets in NY City

# %%
import pandas as pd
from pandas import read_csv
from mpld3 import plugins
from pandas.tools.plotting import scatter_matrix
from mpld3 import plugins
import mpld3
# %pylab inline
mpld3.enable_notebook()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['scatter']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
# Best performers
df = read_csv('features_top_performers.csv', sep = ',')

# %%
# Scatter plot of best parking tickets issuers:
# AM tickets vs PM tickets for (size = tickets category 1)

fig, ax = plt.subplots()
scatter=ax.scatter(df['tickets_am'], df['tickets_pm'], 
                   c = np.random.random(size = df.shape[0]),
                   s=array(df['tickets_cat_1']/5),alpha=0.3, cmap=plt.cm.jet)
ax.set_title('Best issuers in NY (size = violation_cat 1)', size=15)
ax.set_xlabel('tickets AM')
ax.set_ylabel('tickets PM')
ax.grid(color='white', linestyle='solid')
labels = ['issuer# {0}'.format(i) for i in df['issuer_code'].values]

tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el2565444143666082352235005"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
#OBSERVATIONS:
# Best issuers who gave a lot of tickets in the morning gave few tickets in the afternoon, and inversely
# Best issuers who gave a lot of tickets in the afternoon gave few tickets in the morning
# Tickets from category 1 are mostly issued in the morning (big point size)
